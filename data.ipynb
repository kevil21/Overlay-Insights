# %% [markdown]
# # 1. Data Information

# %%
import pandas as pd
import numpy as np

# Dataset
file_path = 'data/IncidentTableData.csv'
df = pd.read_csv(file_path)

# shape
print('Shape of the dataset:', df.shape)

# column names
print('\nColumn names:', df.columns.tolist())

# data types
print('\nData types:')
print(df.dtypes)
# Out:
# Shape of the dataset: (102, 30)
#
# Column names: ['Ticket Class', 'Ticket Priority', 'Ticket Number', 'Ticket Status', 'Ticket Status Original', 'Opened Date', 'Hostname', 'OS Type', 'Ticket Summary', 'Queue ID', 'Ticket Resolved Date', 'Resolution Code', 'Resolution Text', 'Ticket Closed Date', 'Call code', 'Reported By', 'Executed Automata', 'Recommended Automata', 'Actionable', 'Assignment Queue', 'Autogenerated', 'Automation Engine', 'Business Application', 'Closure Code', 'Sub Category', 'Target Finish Date', 'Time to resolve (min)', 'Category', 'Alert Key', 'Comments & Work Notes']
#
# Data types:
# Ticket Class               object
# Ticket Priority             int64
# Ticket Number              object
# Ticket Status              object
# Ticket Status Original     object
# Opened Date                object
# Hostname                   object
# OS Type                    object
# Ticket Summary             object
# Queue ID                   object
# Ticket Resolved Date       object
# Resolution Code            object
# Resolution Text            object
# Ticket Closed Date        float64
# Call code                  object
# Reported By                object
# Executed Automata         float64
# Recommended Automata       object
# Actionable                 object
# Assignment Queue           object
# Autogenerated              object
# Automation Engine         float64
# Business Application       object
# Closure Code              float64
# Sub Category               object
# Target Finish Date        float64
# Time to resolve (min)     float64
# Category                   object
# Alert Key                  object
# Comments & Work Notes     float64
# dtype: object

# %%
# missing values count
print('\nMissing values per column:')
print(df.isnull().sum())
# Out:
# Missing values per column:
# Ticket Class                0
# Ticket Priority             0
# Ticket Number               0
# Ticket Status               0
# Ticket Status Original      0
# Opened Date                 0
# Hostname                    4
# OS Type                     4
# Ticket Summary              0
# Queue ID                    0
# Ticket Resolved Date      101
# Resolution Code             0
# Resolution Text            24
# Ticket Closed Date        102
# Call code                   0
# Reported By                 0
# Executed Automata         102
# Recommended Automata       65
# Actionable                  0
# Assignment Queue            0
# Autogenerated               1
# Automation Engine           3
# Business Application       22
# Closure Code              102
# Sub Category              101
# Target Finish Date        102
# Time to resolve (min)     101
# Category                    0
# Alert Key                   6
# Comments & Work Notes     102
# dtype: int64

# %%
# basic stats
print('\nBasic statistics:')
print(df.describe(include='all'))
# Out:
# Basic statistics:
#        Ticket Class  Ticket Priority Ticket Number Ticket Status  \
# count           102       102.000000           102           102
# unique            1              NaN           102             3
# top        INCIDENT              NaN    IN89157912      SLA HOLD
# freq            102              NaN             1            61
# mean            NaN         1.794118           NaN           NaN
# std             NaN         0.406342           NaN           NaN
# min             NaN         1.000000           NaN           NaN
# 25%             NaN         2.000000           NaN           NaN
# 50%             NaN         2.000000           NaN           NaN
# 75%             NaN         2.000000           NaN           NaN
# max             NaN         2.000000           NaN           NaN
#
#        Ticket Status Original          Opened Date       Hostname OS Type  \
# count                     102                  102             98      98
# unique                      4                   94             64       6
# top                   SLAHOLD  Nov 3, 2025 5:53 PM  conqt464gee9n    UNIX
# freq                       61                    5              5      62
# mean                      NaN                  NaN            NaN     NaN
# std                       NaN                  NaN            NaN     NaN
# min                       NaN                  NaN            NaN     NaN
# 25%                       NaN                  NaN            NaN     NaN
# 50%                       NaN                  NaN            NaN     NaN
# 75%                       NaN                  NaN            NaN     NaN
# max                       NaN                  NaN            NaN     NaN
#
#                           Ticket Summary                     Queue ID  ...  \
# count                                102                          102  ...
# unique                                24                           12  ...
# top     It is Incident Short Description  K-QWQ-KP-FQR-QOF-SPK-DCSQCN  ...
# freq                                  76                           58  ...
# mean                                 NaN                          NaN  ...
# std                                  NaN                          NaN  ...
# min                                  NaN                          NaN  ...
# 25%                                  NaN                          NaN  ...
# 50%                                  NaN                          NaN  ...
# 75%                                  NaN                          NaN  ...
# max                                  NaN                          NaN  ...
#
#        Autogenerated Automation Engine  Business Application  Closure Code  \
# count            101         99.000000                    80           0.0
# unique             1               NaN                    32           NaN
# top                Y               NaN  ACME_DC_Application2           NaN
# freq             101               NaN                    10           NaN
# mean             NaN          0.141414                   NaN           NaN
# std              NaN          0.350222                   NaN           NaN
# min              NaN          0.000000                   NaN           NaN
# 25%              NaN          0.000000                   NaN           NaN
# 50%              NaN          0.000000                   NaN           NaN
# 75%              NaN          0.000000                   NaN           NaN
# max              NaN          1.000000                   NaN           NaN
#
#        Sub Category Target Finish Date  Time to resolve (min) Category  \
# count             1                0.0                    1.0      102
# unique            1                NaN                    NaN        9
# top        Database                NaN                    NaN  unknown
# freq              1                NaN                    NaN       66
# mean            NaN                NaN                    5.0      NaN
# std             NaN                NaN                    NaN      NaN
# min             NaN                NaN                    5.0      NaN
# 25%             NaN                NaN                    5.0      NaN
# 50%             NaN                NaN                    5.0      NaN
# 75%             NaN                NaN                    5.0      NaN
# max             NaN                NaN                    5.0      NaN
#
#                         Alert Key Comments & Work Notes
# count                          96                   0.0
# unique                         40                   NaN
# top     acme002_cneeoq_iqc7_owqcn                   NaN
# freq                           11                   NaN
# mean                          NaN                   NaN
# std                           NaN                   NaN
# min                           NaN                   NaN
# 25%                           NaN                   NaN
# 50%                           NaN                   NaN
# 75%                           NaN                   NaN
# max                           NaN                   NaN
#
# [11 rows x 30 columns]

# %% [markdown]
# # 2. Data Cleaning

# %%
# column name standardization : remove spaces and convert to lowercase
df.columns = [col.strip().replace(' ', '_').lower() for col in df.columns]

# %%
# remove duplicate rows
df.drop_duplicates(inplace=True)

# %% [raw]
# # Handle missing values: fill missing text with 'Unknown' and numeric with 0
# for col in df.columns:
#     if df[col].dtype == 'object':
#         df[col].fillna('Unknown', inplace=True)
#     else:
#         df[col].fillna(0, inplace=True)

# %%
# Correct data types for date columns
date_cols = ['opened_date', 'ticket_resolved_date', 'ticket_closed_date', 'target_finish_date']
for col in date_cols:
    if col in df.columns:
        df[col] = pd.to_datetime(df[col], errors='coerce')

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ticket_class            102 non-null    object
#  1   ticket_priority         102 non-null    int64
#  2   ticket_number           102 non-null    object
#  3   ticket_status           102 non-null    object
#  4   ticket_status_original  102 non-null    object
#  5   opened_date             102 non-null    datetime64[ns]
#  6   hostname                98 non-null     object
#  7   os_type                 98 non-null     object
#  8   ticket_summary          102 non-null    object
#  9   queue_id                102 non-null    object
#  10  ticket_resolved_date    1 non-null      datetime64[ns]
#  11  resolution_code         102 non-null    object
#  12  resolution_text         78 non-null     object
#  13  ticket_closed_date      0 non-null      datetime64[ns]
#  14  call_code               102 non-null    object
#  15  reported_by             102 non-null    object
#  16  executed_automata       0 non-null      float64
#  17  recommended_automata    37 non-null     object
#  18  actionable              102 non-null    object
#  19  assignment_queue        102 non-null    object
#  20  autogenerated           101 non-null    object
#  21  automation_engine       99 non-null     float64
#  22  business_application    80 non-null     object
#  23  closure_code            0 non-null      float64
#  24  sub_category            1 non-null      object
#  25  target_finish_date      0 non-null      datetime64[ns]
#  26  time_to_resolve_(min)   1 non-null      float64
#  27  category                102 non-null    object
#  28  alert_key               96 non-null     object
#  29  comments_&_work_notes   0 non-null      float64
# dtypes: datetime64[ns](4), float64(5), int64(1), object(20)
# memory usage: 24.0+ KB
# None

# %% [markdown]
# # 3. Data Enhancement

# %%
# Extract date features from opened_date
if 'opened_date' in df.columns:
    df['opened_year'] = df['opened_date'].dt.year
    df['opened_month'] = df['opened_date'].dt.month
    df['opened_day'] = df['opened_date'].dt.day
    df['opened_hour'] = df['opened_date'].dt.hour

# %%
# Convert all object columns to string
df = df.astype({col: 'string' for col in df.select_dtypes(include='object').columns})

# %%
# Normalize categorical values: convert to lowercase
categorical_cols = ['ticket_class', 'ticket_priority', 'ticket_status', 'hostname', 'os_type', 'business_application']
for col in categorical_cols:
    if col in df.columns:
        df[col] = df[col].astype('string')
        df[col] = df[col].str.lower()

print(df.head())
# Out:
#   ticket_class ticket_priority ticket_number ticket_status  \
# 0     incident               2    IN89157912   in progress
# 1     incident               1    IN88258016   in progress
# 2     incident               2    IN71887046        queued
# 3     incident               2    IN71887860        queued
# 4     incident               2    IN71841189      sla hold
#
#   ticket_status_original         opened_date       hostname os_type  \
# 0            IN PROGRESS 2025-11-16 04:30:00   fgceogqto405  vmware
# 1            IN PROGRESS 2025-11-16 01:00:00  fgkdoqtqohif5   linux
# 2                 QUEUED 2025-11-15 19:06:00       ngfed139   linux
# 3                 QUEUED 2025-11-15 18:06:00       ngfed139   linux
# 4                SLAHOLD 2025-11-15 14:03:00           <NA>    <NA>
#
#                                       ticket_summary  \
# 0  fgceogqto405 08-CPU load is high on processor ...
# 1  acme /dev/PSYIXPRD::/PRD: : File system usage ...
# 2  edd#ledcb795#SAP: PA1-sappa1as01_PA1_00:Ins:PA...
# 3  edd#ledcb795#SAP: PA1-sappa1as01_PA1_00:Ins:PA...
# 4  [AST] i-Book&RnR Api prd.allocation-api.8080 -...
#
#                                queue_id  ... sub_category target_finish_date  \
# 0           K-PLTools-AIOPs-Americas-L2  ...         <NA>                NaT
# 1                K-QQM-VV-QOM-MRJ-OCSRM  ...         <NA>                NaT
# 2       K-QWQ-KP-FQR-OFF-DCF-QCN-CH-FCP  ...         <NA>                NaT
# 3       K-QWQ-KP-FQR-OFF-DCF-QCN-CH-FCP  ...         <NA>                NaT
# 4  K-QWQ-NN-FQR-OFF-DCF-CEOG-N6QJKNNKPI  ...         <NA>                NaT
#
#   time_to_resolve_(min)             category              alert_key  \
# 0                   NaN     cpu-high-handler       cnn_enn_vsve_ckv
# 1                   5.0         disk-handler     cnn_hqq_i42u_nkpsv
# 2                   NaN  application-handler  gff_cneeoq_iqc6_owqcn
# 3                   NaN  application-handler  gff_cneeoq_iqc6_owqcn
# 4                   NaN  application-handler                   <NA>
#
#   comments_&_work_notes  opened_year opened_month opened_day opened_hour
# 0                   NaN         2025           11         16           4
# 1                   NaN         2025           11         16           1
# 2                   NaN         2025           11         15          19
# 3                   NaN         2025           11         15          18
# 4                   NaN         2025           11         15          14
#
# [5 rows x 34 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 34 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ticket_class            102 non-null    string
#  1   ticket_priority         102 non-null    string
#  2   ticket_number           102 non-null    string
#  3   ticket_status           102 non-null    string
#  4   ticket_status_original  102 non-null    string
#  5   opened_date             102 non-null    datetime64[ns]
#  6   hostname                98 non-null     string
#  7   os_type                 98 non-null     string
#  8   ticket_summary          102 non-null    string
#  9   queue_id                102 non-null    string
#  10  ticket_resolved_date    1 non-null      datetime64[ns]
#  11  resolution_code         102 non-null    string
#  12  resolution_text         78 non-null     string
#  13  ticket_closed_date      0 non-null      datetime64[ns]
#  14  call_code               102 non-null    string
#  15  reported_by             102 non-null    string
#  16  executed_automata       0 non-null      float64
#  17  recommended_automata    37 non-null     string
#  18  actionable              102 non-null    string
#  19  assignment_queue        102 non-null    string
#  20  autogenerated           101 non-null    string
#  21  automation_engine       99 non-null     float64
#  22  business_application    80 non-null     string
#  23  closure_code            0 non-null      float64
#  24  sub_category            1 non-null      string
#  25  target_finish_date      0 non-null      datetime64[ns]
#  26  time_to_resolve_(min)   1 non-null      float64
#  27  category                102 non-null    string
#  28  alert_key               96 non-null     string
#  29  comments_&_work_notes   0 non-null      float64
#  30  opened_year             102 non-null    int32
#  31  opened_month            102 non-null    int32
#  32  opened_day              102 non-null    int32
#  33  opened_hour             102 non-null    int32
# dtypes: datetime64[ns](4), float64(5), int32(4), string(21)
# memory usage: 25.6 KB

# %% [markdown]
# # 4. Derived Fields

# %%
# Resolution Time (hours)
if 'ticket_resolved_date' in df.columns and 'opened_date' in df.columns:
    df['resolution_time_hours'] = (df['ticket_resolved_date'] - df['opened_date']).dt.total_seconds() / 3600

# %%
# Ticket Age (days)
current_time = pd.Timestamp.now()
if 'opened_date' in df.columns:
    df['ticket_age_days'] = (current_time - df['opened_date']).dt.days

# %%
# Is Automated ('executed_automata' column)
if 'executed_automata' in df.columns:
    df['is_automated'] = df['executed_automata'].apply(lambda x: False if x == '' else True)

# %%
# Critical application flag (based on business_application column)
critical_apps = ['payment processing', 'internet banking', 'my web application']
if 'business_application' in df.columns:
    df['critical_application_flag'] = df['business_application'].apply(lambda x: True if isinstance(x, str) and x in critical_apps else False)

# %%
print(df[['resolution_time_hours', 'ticket_age_days', 'is_automated', 'critical_application_flag']].head())
# Out:
#    resolution_time_hours  ticket_age_days  is_automated  \
# 0                    NaN                0          True
# 1               0.083333                0          True
# 2                    NaN                0          True
# 3                    NaN                0          True
# 4                    NaN                1          True
#
#    critical_application_flag
# 0                       True
# 1                       True
# 2                      False
# 3                      False
# 4                      False

# %% [markdown]
# # 5. Cleaned Data Export

# %%
df.to_csv("data/_cleaned.csv", index=False)
